# %% [markdown]
# # Introduction

# %% [markdown]
# Since Jan. 1, 2015, [The Washington Post](https://www.washingtonpost.com/) has been compiling a database of every fatal shooting in the US by a police officer in the line of duty.
#
# <center><img src=https://i.imgur.com/sX3K62b.png></center>
#
# While there are many challenges regarding data collection and reporting, The Washington Post has been tracking more than a dozen details about each killing. This includes the race, age and gender of the deceased, whether the person was armed, and whether the victim was experiencing a mental-health crisis. The Washington Post has gathered this supplemental information from law enforcement websites, local new reports, social media, and by monitoring independent databases such as "Killed by police" and "Fatal Encounters". The Post has also conducted additional reporting in many cases.
#
# There are 4 additional datasets: US census data on poverty rate, high school graduation rate, median household income, and racial demographics. [Source of census data](https://factfinder.census.gov/faces/nav/jsf/pages/community_facts.xhtml).

# %% [markdown]
# ### Upgrade Plotly
#
# Run the cell below if you are working with Google Colab

# %%
# %pip install --upgrade plotly

# %% [markdown]
# ## Import Statements

# %%
import numpy as np
import pandas as pd
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.graph_objects as go

# This might be helpful:
from collections import Counter

# %% [markdown]
# ## Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

# %% [markdown]
# ## Load the Data

# %%
df_hh_income = pd.read_csv('Median_Household_Income_2015.csv', encoding="windows-1252")
df_pct_poverty = pd.read_csv('Pct_People_Below_Poverty_Level.csv', encoding="windows-1252")
df_pct_completed_hs = pd.read_csv('Pct_Over_25_Completed_High_School.csv', encoding="windows-1252")
df_share_race_city = pd.read_csv('Share_of_Race_By_City.csv', encoding="windows-1252")
df_fatalities = pd.read_csv('Deaths_by_Police_US.csv', encoding="windows-1252")

# %% [markdown]
# # Preliminary Data Exploration
#
# * What is the shape of the DataFrames?
# * How many rows and columns do they have?
# * What are the column names?
# * Are there any NaN values or duplicates?

# %%
print(f'{df_hh_income.shape=}')
print(f'{df_pct_completed_hs.shape=}')
print(f'{df_pct_poverty.shape=}')
print(f'{df_share_race_city.shape=}')
print(f'{df_fatalities.shape=}')
# Out:
# df_hh_income.shape=(29322, 3)
# df_pct_completed_hs.shape=(29329, 3)
# df_pct_poverty.shape=(29329, 3)
# df_share_race_city.shape=(29268, 7)
# df_fatalities.shape=(2535, 14)

# %%
df_hh_income.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29322 entries, 0 to 29321
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29322 non-null  object
#  1   City             29322 non-null  object
#  2   Median Income    29271 non-null  object
# dtypes: object(3)
# memory usage: 687.4+ KB

# %%
df_pct_completed_hs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Geographic Area       29329 non-null  object
#  1   City                  29329 non-null  object
#  2   percent_completed_hs  29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
df_pct_poverty.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29329 entries, 0 to 29328
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Geographic Area  29329 non-null  object
#  1   City             29329 non-null  object
#  2   poverty_rate     29329 non-null  object
# dtypes: object(3)
# memory usage: 687.5+ KB

# %%
df_share_race_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  object
#  3   share_black            29268 non-null  object
#  4   share_native_american  29268 non-null  object
#  5   share_asian            29268 non-null  object
#  6   share_hispanic         29268 non-null  object
# dtypes: object(7)
# memory usage: 1.6+ MB

# %%
df_fatalities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2535 entries, 0 to 2534
# Data columns (total 14 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   id                       2535 non-null   int64
#  1   name                     2535 non-null   object
#  2   date                     2535 non-null   object
#  3   manner_of_death          2535 non-null   object
#  4   armed                    2526 non-null   object
#  5   age                      2458 non-null   float64
#  6   gender                   2535 non-null   object
#  7   race                     2340 non-null   object
#  8   city                     2535 non-null   object
#  9   state                    2535 non-null   object
#  10  signs_of_mental_illness  2535 non-null   bool
#  11  threat_level             2535 non-null   object
#  12  flee                     2470 non-null   object
#  13  body_camera              2535 non-null   bool
# ...

# %% [markdown]
# ## Data Cleaning - Check for Missing Values and Duplicates
#
# Consider how to deal with the NaN values. Perhaps substituting 0 is appropriate.

# %%
df_fatalities.isna().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                        9
# age                         77
# gender                       0
# race                       195
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                        65
# body_camera                  0
# dtype: int64

# %%
df_fatalities = df_fatalities.fillna(0)

# %%
df_fatalities.isna().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# dtype: int64

# %%
print(f'{df_hh_income.isna().values.any()=}')
print(f'{df_pct_completed_hs.isna().values.any()=}')
print(f'{df_pct_poverty.isna().values.any()=}')
print(f'{df_share_race_city.isna().values.any()=}')
# Out:
# df_hh_income.isna().values.any()=True
# df_pct_completed_hs.isna().values.any()=False
# df_pct_poverty.isna().values.any()=False
# df_share_race_city.isna().values.any()=False

# %%
df_hh_income = df_hh_income.fillna(0)
df_hh_income.isna().values.any()
# Out:
# False

# %%
print(f'{df_hh_income.duplicated().values.any()=}')
print(f'{df_pct_completed_hs.duplicated().values.any()=}')
print(f'{df_pct_poverty.duplicated().values.any()=}')
print(f'{df_share_race_city.duplicated().values.any()=}')
# Out:
# df_hh_income.duplicated().values.any()=False
# df_pct_completed_hs.duplicated().values.any()=False
# df_pct_poverty.duplicated().values.any()=False
# df_share_race_city.duplicated().values.any()=False

# %% [markdown]
# # Chart the Poverty Rate in each US State
#
# Create a bar chart that ranks the poverty rate from highest to lowest by US state. Which state has the highest poverty rate? Which state has the lowest poverty rate?  Bar Plot

# %%
df_pct_poverty.poverty_rate = df_pct_poverty.poverty_rate.str.replace('-', '0')
df_pct_poverty.poverty_rate = pd.to_numeric(df_pct_poverty.poverty_rate)

# %%
df_pct_poverty = df_pct_poverty.groupby('Geographic Area').poverty_rate.mean().reset_index(name='pct')
df_pct_poverty.sort_values('pct', inplace=True)
df_pct_poverty
# Out:
#    Geographic Area   pct
# 31              NJ  8.16
# 50              WY  9.06
# 6               CT  9.14
# 19              MA  9.55
# 20              MD 10.27
# 39              RI 10.37
# 34              NY 11.64
# 44              UT 11.72
# 28              ND 12.13
# 12              IA 12.23
# 33              NV 12.37
# 38              PA 12.49
# 8               DE 12.56
# 30              NH 12.66
# 48              WI 12.86
# 29              NE 12.92
# 5               CO 13.19
# 11              HI 13.40
# 23              MN 13.75
# 46              VT 13.79
# 14              IL 13.85
# 45              VA 14.59
# 16              KS 14.72
# 47              WA 14.83
# 35              OH 14.83
# 15              IN 15.50
# 41              SD 15.75
# 26              MT 16.42
# 37              OR 16.44
# 4               CA 16.89
# 21              ME 16.89
# 9               FL 17.51
# 22              MI 17.90
# 7               DC 18.00
# 13              ID 18.08
# 0               AK 18.68
# ...

# %%
bar = px.bar(x=df_pct_poverty.pct,
             y=df_pct_poverty['Geographic Area'],
             orientation='h',
             color=df_pct_poverty.pct,
             color_continuous_scale='Viridis',
             title='Poverty Rate in each US State')
bar.update_layout(xaxis_title='Percentage', yaxis_title='State', coloraxis_showscale=False)
bar.show()
# Out:
# <div>                            <div id="362f1c27-a7f0-46fa-b601-9d43a144fefa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("362f1c27-a7f0-46fa-b601-9d43a144fefa")) {                    Plotly.newPlot(                        "362f1c27-a7f0-46fa-b601-9d43a144fefa",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[8.160917431192654,9.063725490196083,9.137499999999996,9.546341463414642,10.272393822393829,10.369444444444444,11.638963210702341,11.724615384615383,12.13192019950125,12.23154761904761,12.37099236641221,12.487173666288305,12.555844155844163,12.659793814432987,12.858687258687258,12.917413793103448,13.187772925764186,13.400662251655
# ...

# %% [markdown]
# # Chart the High School Graduation Rate by US State
#
# Show the High School Graduation Rate in ascending order of US States. Which state has the lowest high school graduation rate? Which state has the highest?

# %%
df_pct_completed_hs.percent_completed_hs = df_pct_completed_hs.percent_completed_hs.str.replace('-', '0')
df_pct_completed_hs.percent_completed_hs = pd.to_numeric(df_pct_completed_hs.percent_completed_hs)

# %%
df_pct_completed_hs = df_pct_completed_hs.groupby('Geographic Area').percent_completed_hs.mean().reset_index(name='pct')
df_pct_completed_hs.sort_values('pct', inplace=True)
df_pct_completed_hs
# Out:
#    Geographic Area   pct
# 43              TX 74.09
# 25              MS 78.47
# 10              GA 78.63
# 32              NM 78.97
# 18              LA 79.12
# 3               AZ 79.22
# 2               AR 79.95
# 0               AK 80.10
# 1               AL 80.16
# 40              SC 80.65
# 4               CA 80.82
# 42              TN 81.63
# 49              WV 82.14
# 17              KY 82.22
# 36              OK 82.46
# 24              MO 82.79
# 27              NC 83.14
# 50              WY 83.97
# 13              ID 84.42
# 45              VA 84.88
# 9               FL 85.46
# 41              SD 86.18
# 15              IN 86.32
# 33              NV 87.05
# 47              WA 87.07
# 28              ND 87.60
# 37              OR 87.60
# 16              KS 87.97
# 20              MD 88.08
# 35              OH 88.20
# 14              IL 88.29
# 8               DE 88.52
# 39              RI 88.83
# 5               CO 88.93
# 38              PA 88.97
# 22              MI 89.21
# ...

# %%
bar = px.bar(x=df_pct_completed_hs.pct,
             y=df_pct_completed_hs['Geographic Area'],
             orientation='h',
             color=df_pct_completed_hs.pct,
             title='High School Graduation Rate by US State')
bar.update_layout(xaxis_title='Percentage', yaxis_title='State', coloraxis_showscale=False)
bar.show()
# Out:
# <div>                            <div id="3f27d078-74ef-4713-8ac7-cd29301dbf01" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3f27d078-74ef-4713-8ac7-cd29301dbf01")) {                    Plotly.newPlot(                        "3f27d078-74ef-4713-8ac7-cd29301dbf01",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[74.08694905552377,78.4707182320442,78.63444976076555,78.97178329571105,79.1223628691983,79.21818181818183,79.94953789279104,80.09802816901407,80.16341880341879,80.64570707070703,80.82463863337709,81.63116279069762,82.14172839506172,82.2175925925926,82.46339165545086,82.79457889641829,83.13680649526385,83.97401960784312,84.4176211
# ...

# %% [markdown]
# # Visualise the Relationship between Poverty Rates and High School Graduation Rates
#
# #### Create a line chart with two y-axes to show if the rations of poverty and high school graduation move together.

# %%
plt.figure(figsize=(12,6))
plt.xticks(rotation=90)

ax1 = plt.gca()
ax2 = plt.twinx()

ax1.plot(df_pct_completed_hs['Geographic Area'], df_pct_completed_hs.pct, '#F24A72')
ax2.plot(df_pct_poverty['Geographic Area'], df_pct_poverty.pct, '#333C83')

ax1.set_xlabel('State')
ax1.set_ylabel('High School Graduation Rates', color='#F24A72')
ax2.set_ylabel('Poverty Rates', color='#333C83')

plt.show()

# %% [markdown]
# #### Now use a Seaborn .jointplot() with a Kernel Density Estimate (KDE) and/or scatter plot to visualise the same relationship

# %%
with sns.axes_style('whitegrid'): 
    h = sns.jointplot(x=df_pct_completed_hs.pct,
                      y=df_pct_poverty.pct,
                      joint_kws={'alpha':0.5},
                      kind='scatter',
                      color='#7900FF',
                      height=8)
    h.ax_joint.set_xlabel('High School Graduation Rates', fontweight='bold')
    h.ax_joint.set_ylabel('Poverty Rates', fontweight='bold')
    h.plot_joint(sns.kdeplot, color="#FD5D5D", zorder=0, levels=6)
#     h.ax_joint.set_title('Relationship between Poverty Rates and High School Graduation Rates')
    
plt.show()

# %% [markdown]
# #### Seaborn's `.lmplot()` or `.regplot()` to show a linear regression between the poverty ratio and the high school graduation ratio.

# %%
plt.figure(figsize=(16,8), dpi=200)
with sns.axes_style('darkgrid'):
    h = sns.regplot(x=df_pct_completed_hs.pct,
                    y=df_pct_poverty.pct,
                    lowess=True,
                    scatter_kws = {'alpha': 0.4},
                    line_kws={'color': '#533E85'})
    
    h.set_xlabel('High School Graduation Rates', fontweight='bold')
    h.set_ylabel('Poverty Rates', fontweight='bold')
    
plt.show()

# %% [markdown]
# # Create a Bar Chart with Subsections Showing the Racial Makeup of Each US State
#
# Visualise the share of the white, black, hispanic, asian and native american population in each US State using a bar chart with sub sections.

# %%
df_share_race_city.share_white = df_share_race_city.share_white.str.replace(r'[(X)]', '0')
df_share_race_city.share_black = df_share_race_city.share_black.str.replace(r'[(X)]', '0')
df_share_race_city.share_native_american = df_share_race_city.share_native_american.str.replace(r'[(X)]', '0')
df_share_race_city.share_asian = df_share_race_city.share_asian.str.replace(r'[(X)]', '0')
df_share_race_city.share_hispanic = df_share_race_city.share_hispanic.str.replace(r'[(X)]', '0')
# Out:
# <ipython-input-150-ec724ec9cb38>:1: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-150-ec724ec9cb38>:2: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-150-ec724ec9cb38>:3: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-150-ec724ec9cb38>:4: FutureWarning:
#
# The default value of regex will change from True to False in a future version.
#
# <ipython-input-150-ec724ec9cb38>:5: FutureWarning:
#
# The default value of regex will change from True to False in a future version.

# %%
df_share_race_city.share_white = pd.to_numeric(df_share_race_city.share_white)
df_share_race_city.share_black = pd.to_numeric(df_share_race_city.share_black)
df_share_race_city.share_native_american = pd.to_numeric(df_share_race_city.share_native_american)
df_share_race_city.share_asian = pd.to_numeric(df_share_race_city.share_asian)
df_share_race_city.share_hispanic = pd.to_numeric(df_share_race_city.share_hispanic)
df_share_race_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29268 entries, 0 to 29267
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Geographic area        29268 non-null  object
#  1   City                   29268 non-null  object
#  2   share_white            29268 non-null  float64
#  3   share_black            29268 non-null  float64
#  4   share_native_american  29268 non-null  float64
#  5   share_asian            29268 non-null  float64
#  6   share_hispanic         29268 non-null  float64
# dtypes: float64(5), object(2)
# memory usage: 1.6+ MB

# %%
df_share_race_city = df_share_race_city.groupby('Geographic area').agg({'share_white': 'mean',
                                                                        'share_black': 'mean',
                                                                        'share_native_american': 'mean',
                                                                        'share_asian': 'mean',
                                                                        'share_hispanic': 'mean'}).reset_index()

# %%
bar = px.bar(df_share_race_city,
             x='Geographic area',
             y=['share_white', 'share_black', 'share_native_american', 'share_asian', 'share_hispanic'],
             title='Racial Makeup of Each US State',
             )

bar.update_layout(xaxis_tickangle=90, xaxis_title='State', yaxis_title='Percentage')

bar.show()
# Out:
# <div>                            <div id="aca00ddd-2363-4aff-b776-4b379e550c21" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("aca00ddd-2363-4aff-b776-4b379e550c21")) {                    Plotly.newPlot(                        "aca00ddd-2363-4aff-b776-4b379e550c21",                        [{"alignmentgroup":"True","hovertemplate":"variable=share_white<br>Geographic area=%{x}<br>value=%{y}<extra></extra>","legendgroup":"share_white","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"share_white","offsetgroup":"share_white","orientation":"v","showlegend":true,"textposition":"auto","type":"bar","x":["AK","AL","AR","AZ","CA","CO","CT","DC","DE","FL","GA","HI","IA","ID","IL","IN","KS","KY","LA","MA","MD","ME","MI","MN","MO","MS","MT","NC","ND",
# ...

# %% [markdown]
# # Create Donut Chart by of People Killed by Race
#
# Hint: Use `.value_counts()`

# %%
white = df_share_race_city.share_white.value_counts().reset_index()
black = df_share_race_city.share_black.value_counts().reset_index()
native = df_share_race_city.share_native_american.value_counts().reset_index()
asian = df_share_race_city.share_asian.value_counts().reset_index()
hispanic = df_share_race_city.share_hispanic.value_counts().reset_index()

data = {'Race': ['White', 'Black', 'Native', 'Asian', 'Hispanic'],
        'Percentage': [white['index'].mean(),
                       black['index'].mean(),
                       native['index'].mean(),
                       asian['index'].mean(),
                       hispanic['index'].mean()]}

pie_df = pd.DataFrame(data)

# %%
pie = px.pie(pie_df,
             labels='Race',
             values='Percentage',
             names='Race',
             title='People Killed by Race',
             color_discrete_sequence=px.colors.sequential.RdBu)

pie.update_traces(textinfo='percent+label')
pie.show()
# Out:
# <div>                            <div id="1e1eb13c-10e0-424b-b596-b9a06095e577" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e1eb13c-10e0-424b-b596-b9a06095e577")) {                    Plotly.newPlot(                        "1e1eb13c-10e0-424b-b596-b9a06095e577",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hovertemplate":"Race=%{label}<br>Percentage=%{value}<extra></extra>","labels":["White","Black","Native","Asian","Hispanic"],"legendgroup":"","name":"","showlegend":true,"textinfo":"percent+label","type":"pie","values":[80.92842395916004,7.829365498973834,3.6010291958545055,1.8411609261637631,7.741114587765574]}],                        {"legend":{"tracegroupgap":0},"piecolorway":["rgb(103,0,31)","rgb(178,24,43)","rgb(214,9
# ...

# %% [markdown]
# # Create a Chart Comparing the Total Number of Deaths of Men and Women
#
# Use `df_fatalities` to illustrate how many more men are killed compared to women.

# %%
m_f = df_fatalities.gender.value_counts()

# %%
bar = px.bar(x=m_f.index,
             y=m_f.values,
             color=m_f.values,
             title='Number of Deaths of Men and Women')

bar.update_layout(xaxis_title='Sex', yaxis_title='Deaths', coloraxis_showscale=False)
bar.show()
# Out:
# <div>                            <div id="ac46278b-ffb9-41d8-8473-861426abfeeb" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ac46278b-ffb9-41d8-8473-861426abfeeb")) {                    Plotly.newPlot(                        "ac46278b-ffb9-41d8-8473-861426abfeeb",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[2428,107],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["M","F"],"xaxis":"x","y":[2428,107],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorbar":{"title":{"text":"color"}},"colorscale":[[0.0,"#0
# ...

# %% [markdown]
# # Create a Box Plot Showing the Age and Manner of Death
#
# Break out the data by gender using `df_fatalities`. Is there a difference between men and women in the manner of death?

# %%
box = px.box(df_fatalities,
             x='gender',
             y='age',
             color='manner_of_death',
             title='Age and Manner of Death by Gender')
box.show()
# Out:
# <div>                            <div id="51f93a25-739a-481a-b6f9-5ad005dc8840" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("51f93a25-739a-481a-b6f9-5ad005dc8840")) {                    Plotly.newPlot(                        "51f93a25-739a-481a-b6f9-5ad005dc8840",                        [{"alignmentgroup":"True","hovertemplate":"manner_of_death=shot<br>gender=%{x}<br>age=%{y}<extra></extra>","legendgroup":"shot","marker":{"color":"#636efa"},"name":"shot","notched":false,"offsetgroup":"shot","orientation":"v","showlegend":true,"type":"box","x":["M","M","M","M","M","M","M","F","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M","M
# ...

# %% [markdown]
# # Were People Armed?
#
# In what percentage of police killings were people armed? Create chart that show what kind of weapon (if any) the deceased was carrying. How many of the people killed by police were armed with guns versus unarmed?

# %%
df_fatalities.armed.value_counts()
# Out:
# gun                 1398
# knife                373
# vehicle              177
# unarmed              171
# undetermined         117
#                     ...
# pole and knife         1
# crowbar                1
# lawn mower blade       1
# metal hand tool        1
# tire iron              1
# Name: armed, Length: 69, dtype: int64

# %%
bar = px.bar(x=df_fatalities.armed.value_counts().index,
             y=df_fatalities.armed.value_counts().values)
bar.show()
# Out:
# <div>                            <div id="e434cdf5-4791-4d70-a6ed-2923babf5466" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e434cdf5-4791-4d70-a6ed-2923babf5466")) {                    Plotly.newPlot(                        "e434cdf5-4791-4d70-a6ed-2923babf5466",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":["gun","knife","vehicle","unarmed","undetermined","toy weapon","machete","unknown weapon",0,"Taser","ax","sword","baseball bat","box cutter","metal pipe","hammer","crossbow","hatchet","gun and knife","screwdriver","blunt
# ...

# %% [markdown]
# # How Old Were the People Killed?

# %% [markdown]
# Work out what percentage of people killed were under 25 years old.

# %%
df_fatalities[df_fatalities.age < 25].shape[0] / df_fatalities.shape[0] *100
# Out:
# 20.78895463510848

# %% [markdown]
# Create a histogram and KDE plot that shows the distribution of ages of the people killed by police.

# %%
plt.figure(figsize=(16,8), dpi=200)
with sns.axes_style('whitegrid'): 
    h = sns.histplot(df_fatalities[df_fatalities.age !=0],
                     x='age',
                     kde=True,
                     color='#A63EC5')
    
    h.set_xlabel('Age', fontweight='bold')
    h.set_ylabel('Number of Deaths', fontweight='bold')
    h.set_title('Ages of the People Killed by Police')
    
plt.show()

# %% [markdown]
# Create a seperate KDE plot for each race. Is there a difference between the distributions?

# %%
sea = sns.FacetGrid(df_fatalities[df_fatalities.race != 0],
                    row='race')
sea.map(sns.kdeplot, 'age')

# %% [markdown]
# # Race of People Killed
#
# Create a chart that shows the total number of people killed by race.

# %%
bar = px.bar(x=df_fatalities.groupby('race').size().index,
             y=df_fatalities.groupby('race').size().values,
             color=df_fatalities.groupby('race').size().values,
             title='Race of People Killed')

bar.update_layout(xaxis_title='Race', yaxis_title='Number of Deaths', coloraxis_showscale=False)

bar.show()
# Out:
# <div>                            <div id="36e3de0c-e099-41cd-a1b0-24587dca1ed5" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("36e3de0c-e099-41cd-a1b0-24587dca1ed5")) {                    Plotly.newPlot(                        "36e3de0c-e099-41cd-a1b0-24587dca1ed5",                        [{"alignmentgroup":"True","hovertemplate":"x=%{x}<br>y=%{y}<br>color=%{marker.color}<extra></extra>","legendgroup":"","marker":{"color":[195,39,618,423,31,28,1201],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","type":"bar","x":[0,"A","B","H","N","O","W"],"xaxis":"x","y":[195,39,618,423,31,28,1201],"yaxis":"y"}],                        {"barmode":"relative","coloraxis":{"colorba
# ...

# %% [markdown]
# # Mental Illness and Police Killings
#
# What percentage of people killed by police have been diagnosed with a mental illness?

# %%
mental = df_fatalities.signs_of_mental_illness.value_counts().reset_index()

# %%
pct = mental[mental['index'] == True].signs_of_mental_illness.values / df_fatalities.shape[0] * 100

# %%
pct
# Out:
# array([24.9704142])

# %% [markdown]
# # In Which Cities Do the Most Police Killings Take Place?
#
# Create a chart ranking the top 10 cities with the most police killings. Which cities are the most dangerous?

# %%
dan_cities = df_fatalities.city.value_counts()[:10].reset_index(name='Count')

# %%
bar = px.bar(dan_cities,
             x='Count',
             y='index',
             orientation='h',
             title='Top 10 Citites by Police Killings',
             color='Count')

bar.update_layout(xaxis_title='Number of Deaths', yaxis_title='City', coloraxis_showscale=False)

bar.show()
# Out:
# <div>                            <div id="a1797180-500b-4f72-a77f-d25b134a46cf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a1797180-500b-4f72-a77f-d25b134a46cf")) {                    Plotly.newPlot(                        "a1797180-500b-4f72-a77f-d25b134a46cf",                        [{"alignmentgroup":"True","hovertemplate":"Count=%{marker.color}<br>index=%{y}<extra></extra>","legendgroup":"","marker":{"color":[39,31,27,25,21,20,19,18,18,15],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"h","showlegend":false,"textposition":"auto","type":"bar","x":[39,31,27,25,21,20,19,18,18,15],"xaxis":"x","y":["Los Angeles","Phoenix","Houston","Chicago","Las Vegas","San Antonio","Columbus","Austin","Miami","St. Lou
# ...

# %% [markdown]
# # Rate of Death by Race
#
# Find the share of each race in the top 10 cities. Contrast this with the top 10 cities of police killings to work out the rate at which people are killed by race for each city.

# %%
top_10_cities = df_fatalities.city.value_counts()[:10].index

# %%
top_10_cities = df_fatalities[df_fatalities.city.isin(top_10_cities)]

# %%
top_10_cities
# Out:
#         id                            name      date manner_of_death    armed  \
# 12      22  Hashim Hanif Ibn Abdul-Rasheed  07/01/15            shot    knife
# 40      75                      Pablo Meza  17/01/15            shot      gun
# 48      90                    Isaac Holmes  21/01/15            shot      gun
# 52     336            Robert Francis Mesch  23/01/15            shot      gun
# 64     348             Nicolas Leland Tewa  27/01/15            shot  vehicle
# ...    ...                             ...       ...             ...      ...
# 2508  2793                  Isaiah Perkins  20/07/17            shot      gun
# 2515  2798                  Jerrod Kershaw  24/07/17            shot      gun
# 2520  2804                           TK TK  26/07/17            shot      gun
# 2521  2806                           TK TK  26/07/17            shot      gun
# 2524  2816      Jerauld Phillip Hammond II  27/07/17            shot      gun
#
# ...

# %%
top_race = top_10_cities.groupby(['city', 'race']).size().reset_index(name='Count')

# %%
bar = px.bar(top_race,
             x='Count',
             y='city',
             orientation='h',
             title='Top 10 Citites by Police Killings',
             color='race')

bar.update_layout(xaxis_title='Number of Deaths', yaxis_title='City', coloraxis_showscale=False)

bar.show()
# Out:
# <div>                            <div id="76ff9040-530c-43c5-92f5-740f63491a1b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("76ff9040-530c-43c5-92f5-740f63491a1b")) {                    Plotly.newPlot(                        "76ff9040-530c-43c5-92f5-740f63491a1b",                        [{"alignmentgroup":"True","hovertemplate":"race=B<br>Count=%{x}<br>city=%{y}<extra></extra>","legendgroup":"B","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"B","offsetgroup":"B","orientation":"h","showlegend":true,"textposition":"auto","type":"bar","x":[3,21,11,15,3,10,8,2,3,11],"xaxis":"x","y":["Austin","Chicago","Columbus","Houston","Las Vegas","Los Angeles","Miami","Phoenix","San Antonio","St. Louis"],"yaxis":"y"},{"alignmentgroup":"True","hoverte
# ...

# %% [markdown]
# # Create a Choropleth Map of Police Killings by US State
#
# Which states are the most dangerous? Compare your map with your previous chart. Are these the same states with high degrees of poverty?

# %%
states = df_fatalities.state.value_counts().reset_index(name='Count')
states
# Out:
#    index  Count
# 0     CA    424
# 1     TX    225
# 2     FL    154
# 3     AZ    118
# 4     OH     79
# 5     OK     78
# 6     CO     74
# 7     GA     70
# 8     NC     69
# 9     MO     64
# 10    WA     62
# 11    IL     62
# 12    TN     59
# 13    LA     57
# 14    NM     51
# 15    PA     51
# 16    AL     50
# 17    VA     47
# 18    NY     45
# 19    SC     44
# 20    WI     43
# 21    IN     43
# 22    KY     43
# 23    NV     42
# 24    MD     38
# 25    OR     38
# 26    MI     37
# 27    NJ     35
# 28    MN     32
# 29    WV     27
# 30    AR     26
# 31    KS     24
# 32    UT     23
# 33    MS     23
# 34    MA     22
# 35    ID     17
# 36    AK     15
# 37    NE     15
# 38    ME     13
# 39    IA     12
# 40    HI     11
# 41    MT     11
# 42    DC     11
# 43    SD     10
# 44    CT      9
# 45    DE      8
# 46    WY      8
# 47    NH      7
# 48    ND      4
# 49    VT      3
# 50    RI      2

# %%
fig = go.Figure(data=go.Choropleth(
                locations=states['index'],
                z=states['Count'],
                locationmode='USA-states',
                colorscale='Greens',
                colorbar_title="Number of Deaths"))

fig.update_layout(
    title_text = 'Police Killings by US State',
    geo_scope='usa', # limite map scope to USA
)

fig.show()
# Out:
# <div>                            <div id="7c317665-b938-4e84-b610-c51de57d7b31" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7c317665-b938-4e84-b610-c51de57d7b31")) {                    Plotly.newPlot(                        "7c317665-b938-4e84-b610-c51de57d7b31",                        [{"colorbar":{"title":{"text":"Number of Deaths"}},"colorscale":[[0.0,"rgb(247,252,245)"],[0.125,"rgb(229,245,224)"],[0.25,"rgb(199,233,192)"],[0.375,"rgb(161,217,155)"],[0.5,"rgb(116,196,118)"],[0.625,"rgb(65,171,93)"],[0.75,"rgb(35,139,69)"],[0.875,"rgb(0,109,44)"],[1.0,"rgb(0,68,27)"]],"locationmode":"USA-states","locations":["CA","TX","FL","AZ","OH","OK","CO","GA","NC","MO","WA","IL","TN","LA","NM","PA","AL","VA","NY","SC","WI","IN","KY","NV","MD","OR","MI","N
# ...

# %% [markdown]
# # Number of Police Killings Over Time
#
# Analyse the Number of Police Killings over Time. Is there a trend in the data?

# %%
df_fatalities.date = pd.to_datetime(df_fatalities.date)

# %%
df_fatalities.sort_values('date', inplace=True)

# %%
line = px.line(x=df_fatalities.date)
line.show()
# Out:
# <div>                            <div id="c37f6c0a-94bf-4f82-a111-ea65e4e45a7e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c37f6c0a-94bf-4f82-a111-ea65e4e45a7e")) {                    Plotly.newPlot(                        "c37f6c0a-94bf-4f82-a111-ea65e4e45a7e",                        [{"hovertemplate":"x=%{x}<br>y=%{y}<extra></extra>","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"mode":"lines","name":"","showlegend":false,"type":"scattergl","x":["2015-01-03T00:00:00","2015-01-03T00:00:00","2015-01-03T00:00:00","2015-01-04T00:00:00","2015-01-04T00:00:00","2015-01-06T00:00:00","2015-01-07T00:00:00","2015-01-07T00:00:00","2015-01-08T00:00:00","2015-01-08T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","2015-01-09T00:00:00","20
# ...

# %% [markdown]
# # Epilogue
#
# Now that you have analysed the data yourself, read [The Washington Post's analysis here](https://www.washingtonpost.com/graphics/investigations/police-shootings-database/).
